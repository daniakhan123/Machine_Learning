# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("cancer.csv")
sns.countplot(x='Gender', data=df)
plt.title("Distribution of Gender")
plt.show()


df['Age'].hist(bins=30, color='skyblue', edgecolor='black')
plt.title("Age Distribution")
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.show()


sns.boxplot(x='Smoking', data=df)
plt.title("Boxplot of Smoking")
plt.show()

# %%
corr_matrix = df.corr(numeric_only=True)


plt.figure(figsize=(12, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title("Correlation Heatmap")
plt.show()

# %%
sns.histplot(df['Age'], kde=True, color='green')
plt.title("Distribution of Age")
plt.xlabel("Age")
plt.ylabel("Density")
plt.show()

sns.histplot(df['Frequent Cold'], kde=True, color='purple')
plt.title("Distribution of Frequent Cold")
plt.xlabel("Frequent Cold")
plt.ylabel("Density")
plt.show()

# %%
sns.boxplot(x=df['Obesity'])
plt.title("Outliers in Obesity Feature (Boxplot)")
plt.show()

sns.violinplot(x=df['Obesity'])
plt.title("Distribution & Outliers in Obesity (Violin Plot)")
plt.show()
